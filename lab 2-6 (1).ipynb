# %%
pip install gekko
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scipy

# %%
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt

# %%
def cubicinterpolation():
    x_pts = np.linspace(0,2*np.pi,10) #10 number of points(equidistant) #domain points
    y_pts = np.sin(x_pts)
    x_vals = np.linspace(0,2*np.pi,50) #jo function interpolate krna hai uski domain hai
    
    f = interpolate.interp1d(x_pts,y_pts,'cubic')
    y_vals = f(x_vals) #cubic interpolation, main program
    
    plt.plot(x_pts,y_pts,'o')#plot known data points
    plt.plot(x_vals,y_vals,'-x') #plot interpolated points
    plt.show()

# %%
cubicinterpolation()

# %%
def cubicinterpolation():
    x_pts=np.linspace(0,2*np.pi,10) #10 number of points(equidistant) #domain points
    y_pts= np.sin(x_pts)
    x_vals= np.linspace(0,2*np.pi,50) #jo function interpolate krna hai uski domain hai
    
    spline = interpolate.splrep(x_pts,y_pts)
    y_vals = interploate.splev(x_vals,splines) #cubic interpolation, main program
    
    plt.plot(x_pts,y_pts,'o')#plot known data points
    plt.plot(x_vals,y_vals,'-x') #plot interpolated points
    plt.show()

# %%
cubicinterpolation()

# %%
def cubicinterpolation():
    x_pts=np.linspace(0,2*np.pi,10) #10 number of points(equidistant) #domain points
    y_pts= np.sin(x_pts)
    x_vals= np.linspace(0,2*np.pi,50) #jo function interpolate krna hai uski domain hai
    
    f = interpolate.interp1d(x_pts,y_pts,'linear')
    y_vals = f(x_vals) #cubic interpolation, main program
    
    plt.plot(x_pts,y_pts,'o')#plot known data points
    plt.plot(x_vals,y_vals,'-x') #plot interpolated points
    plt.show()

# %%
cubicinterpolation()

# %%
def cubicinterpolation():
    x_pts=np.linspace(0,2*np.pi,10) #10 number of points(equidistant) #domain points
    y_pts= np.sin(x_pts)
    x_vals= np.linspace(0,2*np.pi,50) #jo function interpolate krna hai uski domain hai
    
    f = interpolate.interp1d(x_pts,y_pts,'quadratic')
    y_vals = f(x_vals) #quadratic interpolation, main program
    
    plt.plot(x_pts,y_pts,'o')#plot known data points
    plt.plot(x_vals,y_vals,'-x') #plot interpolated points
    plt.show()

# %%
cubicinterpolation()

# %%
#interpolation
x = np.linspace(0,100,50)
y = x**2 * np.sin(x)
plt.scatter(x,y)

# %%
from scipy.interpolate import interp1d

# %%
f  = interp1d(x,y,kind = 'cubic')
x_pred = np.linspace(0,20,50)
y_pred = f(x_pred)

# %%
plt.plot(x_pred,y_pred)

# %%
f  = interp1d(x,y,kind = 'linear')
x_pred = np.linspace(0,20,50)
y_pred = f(x_pred)

# %%
plt.plot(x_pred,y_pred)
